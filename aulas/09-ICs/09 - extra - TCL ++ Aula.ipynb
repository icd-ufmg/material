# %%
# -*- coding: utf8

from scipy import stats as ss

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Para evitar a confusão da aula passada, colocando alguns defaults!
plt.rcParams['figure.figsize']  = (18, 10)
plt.rcParams['axes.labelsize']  = 20
plt.rcParams['axes.titlesize']  = 20
plt.rcParams['legend.fontsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20
plt.rcParams['lines.linewidth'] = 4

# %%
plt.ion()

plt.style.use('seaborn-colorblind')
plt.rcParams['figure.figsize']  = (12, 8)

# %%
# pop 
pop = np.round(np.random.beta(4, 2.5, size=20000) * 100)

# %%
plt.title('Notas por Disciplinas na UFMG')
plt.hist(pop, edgecolor='k', bins=20);

# %%
sample_size = 50

# %%
sample_means = []
for _ in range(1000):
    sample = np.random.choice(pop, size=sample_size)
    sample_means.append(sample.mean())

# %%
plt.title('Sample Distribution')
plt.hist(sample_means, edgecolor='k', bins=20);

# %%
one_sample = np.random.choice(pop, size=sample_size)
sample_mean = one_sample.mean()
sample_sd = one_sample.std(ddof=1)

# %%
estimator_sd = sample_sd / np.sqrt(sample_size)

# %%
x = np.linspace(55, 68, 100)
x
# Out:
# array([55.        , 55.13131313, 55.26262626, 55.39393939, 55.52525253,
#        55.65656566, 55.78787879, 55.91919192, 56.05050505, 56.18181818,
#        56.31313131, 56.44444444, 56.57575758, 56.70707071, 56.83838384,
#        56.96969697, 57.1010101 , 57.23232323, 57.36363636, 57.49494949,
#        57.62626263, 57.75757576, 57.88888889, 58.02020202, 58.15151515,
#        58.28282828, 58.41414141, 58.54545455, 58.67676768, 58.80808081,
#        58.93939394, 59.07070707, 59.2020202 , 59.33333333, 59.46464646,
#        59.5959596 , 59.72727273, 59.85858586, 59.98989899, 60.12121212,
#        60.25252525, 60.38383838, 60.51515152, 60.64646465, 60.77777778,
#        60.90909091, 61.04040404, 61.17171717, 61.3030303 , 61.43434343,
#        61.56565657, 61.6969697 , 61.82828283, 61.95959596, 62.09090909,
#        62.22222222, 62.35353535, 62.48484848, 62.61616162, 62.74747475,
#        62.87878788, 63.01010101, 63.14141414, 63.27272727, 63.4040404 ,
# ...

# %%
norm = ss.distributions.norm(one_sample.mean(), estimator_sd)
y = norm.pdf(x)

# %%
plt.plot(x, y)
